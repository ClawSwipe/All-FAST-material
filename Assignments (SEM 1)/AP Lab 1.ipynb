# %% [markdown]
# ##**Chapter 3**
# #**Conditional execution**
# ###**3.1 Boolean expressions**
# ####A *boolean expression* is an expression that is either true or false. The following examples use the operator ==, which compares two operands and produces True if they are equal and False otherwise:

# %% [markdown]
# #**List of astronomical objects**
# 1. Moon Midas and Ida, an asteroid with it's own moon.
# 2. Comet Lovejoy and Jupiter, a giant gas planet.
# 3. The Sun; Sirius A and Sirius B, a white dwarf; the Crab Nebula, a remnant supernova.
# 4. A black hole (artist concept); Vela Pulsar a rotating neuron star.
# 5. M80, a globular cluster, and the Pleaides, an open star cluster.

# %% [markdown]
# #**Galaxy groups and clusters**
# * List of galaxy groups
# * List of galaxy clusters
#   * List of Abell clusters
# * List of galaxy superclusters
#
# #**Black holes**
# * Lists of black holes
#   * List of black holes
#   * List of most massive black holes
#   * List of nearest black holes
